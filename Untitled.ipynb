# %%
import pandas as pd 
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters 
import seaborn as sns

df = pd.read_excel('climate1.xlsx')
df
# Out:
#      Year  Sealevel  Seatemgap
# 0    1891       9.5         -4
# 1    1892      12.7         -5
# 2    1893      17.4         -5
# 3    1894       7.7         -5
# 4    1895      19.5         -4
# ..    ...       ...        ...
# 118  2009     216.7          1
# 119  2010     224.4          1
# 120  2011     226.0          0
# 121  2012     234.8          1
# 122  2013     226.4          1
#
# [123 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Sealevel', 'Seatemgap'], dtype='object')

# %%
df.set_index( 'Year', inplace=True)

# %%
df.head(3)
# Out:
#       Sealevel  Seatemgap
# Year
# 1891       9.5         -4
# 1892      12.7         -5
# 1893      17.4         -5

# %%
plt.plot(df)
plt.show()

# %%
_ = df.plot( kind= 'bar' , secondary_y= 'seatemgap' , rot= 0 )
plt.show()

# %%
x=df.index
y=df.Seatemgap
a=plt.plot(x,y,color="y")
plt.title("Seatemgap")
# Out:
# Text(0.5, 1.0, 'Seatemgap')

# %%
x=df.index
y1=df.Sealevel
y2=df.Seatemgap


# plt.xlabel("Year")
# plt.ylabel("Sealevel")

# 차트 제목
plt.title("Sealevel and Sea Tem gap")

plt.plot(x,y1, label ="Sealevel")
plt.plot(x,y2, label ="Seatemgap")
plt.legend(loc=0)

# %%
import matplotlib.pyplot as plt
x=df.index
y1=df["Seatemgap"]
y2=df["Sealevel"]

fig, ax1=plt.subplots()
ax2=ax1.twinx()

curve1= ax1.plot(x,y1, label="Sealevel", color="r")
curve2= ax1.plot(x,y2, label="Seatemgap", color="b")
plt.plot()
plt.show()

# plt.title("sealevel")
# plt.plot(x,y1, label ="Sealevel")
# plt.plot(x,y2, label ="Seatemgap")
# plt.legend(loc=0)        

# plt.plot()
# plt.show()
